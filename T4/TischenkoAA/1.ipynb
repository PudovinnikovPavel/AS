# %%
import random
import time
import math
def Sort (arr):
    b = [[] * 1 for i in range(10**math.ceil(0.5*math.log10(len(arr))))]
    for i in range (len(arr)):
        b[arr[i]//10**math.ceil(0.5*math.log10(len(arr)))].append(arr[i])
    for i in range (10**math.ceil(0.5*math.log10(len(arr)))):
        b[i]=sorted(b[i])
    index=0
    for i in range (10**math.ceil(0.5*math.log10(len(arr)))):
        for j in range (len(b[i])):
            arr[index]=b[i][j]
            index+=1
arr=[]
n = int(input("Кол-во элементов:"))
for i in range (n):
    arr.append(random.randint(0,1000))
t1 = time.time()
Sort(arr)
t2 = time.time()
print ("Время сортировки:",t2-t1)
# Out:
# 696
# 573
# 530
# 302
# 942
# 785
# 722
# 968
# 160
# 735
# 436
# 825
# 717
# 323
# 293
# 942
# 604
# 536
# 794
# 299
# 700
# 838
# 874
# 897
# 99
# 188
# 143
# 244
# 916
# 91
# 504
# 168
# 602
# 399
# 348
# 86
# 412
# 469
# 144
# 438
# 949
# 272
# 641
# 904
# 348
# 326
# 914
# 708
# 554
# 385
# 298
# 884
# 730
# 216
# 413
# 401
# 472
# 14
# 158
# 80
# 118
# 966
# 919
# 288
# 796
# 13
# 155
# 608
# 845
# 96
# 932
# 574
# 99
# 217
# 255
# 625
# 23
# 566
# 913
# 45
# 321
# 365
# 213
# 862
# 667
# 571
# 597
# 61
# 673
# 787
# 764
# 847
# 467
# 885
# 246
# 97
# 150
# 729
# 698
# 143
# 956
# 43
# 12
# 361
# 238
# 406
# 849
# 385
# 74
# 28
# 596
# 85
# 714
# 778
# 354
# 852
# 666
# 382
# 300
# 235
# 787
# 316
# 428
# 624
# 512
# 408
# 260
# 278
# 679
# 718
# 494
# 51
# 458
# 194
# 730
# 578
# 333
# 724
# 292
# 981
# 112
# 367
# 412
# 370
# 241
# 14
# 464
# 253
# 780
# 994
# 34
# 385
# 492
# 221
# 908
# 213
# 100
# 890
# 691
# 482
# 977
# 703
# 398
# 363
# 923
# 965
# 59
# 952
# 315
# 337
# ...
